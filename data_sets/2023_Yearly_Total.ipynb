# %%
#Import libraries 
import pandas as pd

# %%
# Read in all csv stats categories
AstPerGame = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/AstPerGame_2023.csv')
AstTORatio = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/AstTORatio_2023.csv')
BlocksPerGame = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/BlocksPerGame_2023.csv')
FldGlPct = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/FldGl%_2023.csv')
FldGlPctDef = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/FldGl%Def_2023.csv')
FoulsPerGame = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/FoulsPerGame_2023.csv')
FTPct = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/FT%_2023.csv')
ReboundMargin = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/ReboundMargin_2023.csv')
ScoringDefense = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/ScoringDefense_2023.csv')
ScoringMargin = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/ScoringMargin_2023.csv')
ScoringOffense = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/ScoringOffense_2023.csv')
StlsPerGame = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/StlsPerGame_2023.csv')
ThreePtFGPct = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/ThreePtFG%_2023.csv')
ThreePtFGDef = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/ThreePtFGDef_2023.csv')
ThreePtFGPerGame = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/ThreePtFGPerGame_2023.csv')
TOMargin = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/TOMargin_2023.csv')
TOPerGame = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/TOPerGame_2023.csv')
WLPct = pd.read_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/WL%_2023.csv')

# %%
AstPerGame.head()
# Out:
#    Rank                            Team  GM    W-L  AST   APG
# 0    29  A&M-Corpus Christi (Southland)  33  23-10  518  15.7
# 1    28         Abilene Christian (WAC)  30  13-17  471  15.7
# 2    39       Air Force (Mountain West)  32  14-18  491  15.3
# 3   153                     Akron (MAC)  33  22-11  443  13.4
# 4   202              Alabama A&M (SWAC)  33  15-18  419  12.7

# %%
AstPerGame.rename(columns = {'Rank':'AstPerGame_Rank'}, inplace = True)
AstTORatio.rename(columns = {'Rank':'AstTORatio_Rank'}, inplace = True)
BlocksPerGame.rename(columns = {'Rank':'BlocksPerGame_Rank'}, inplace = True)
FldGlPct.rename(columns = {'Rank':'FldGlPct_Rank'}, inplace = True)
FldGlPctDef.rename(columns = {'Rank':'FldGlPctDef_Rank'}, inplace = True)
FoulsPerGame.rename(columns = {'Rank':'FoulsPerGame_Rank'}, inplace = True)
FTPct.rename(columns = {'Rank':'FTPct_Rank'}, inplace = True)
ReboundMargin.rename(columns = {'Rank':'ReboundMargin_Rank'}, inplace = True)
ScoringDefense.rename(columns = {'Rank':'ScoringDefense_Rank'}, inplace = True)
ScoringMargin.rename(columns = {'Rank':'ScoringMargin_Rank'}, inplace = True)
ScoringOffense.rename(columns = {'Rank':'ScoringOffense_Rank'}, inplace = True)
StlsPerGame.rename(columns = {'Rank':'StlsPerGame_Rank'}, inplace = True)
ThreePtFGPct.rename(columns = {'Rank':'ThreePtFGPct_Rank'}, inplace = True)
ThreePtFGDef.rename(columns = {'Rank':'ThreePtFGDef_Rank'}, inplace = True)
ThreePtFGPerGame.rename(columns = {'Rank':'ThreePtFGPerGame_Rank'}, inplace = True)
TOMargin.rename(columns = {'Rank':'TOMargin_Rank'}, inplace = True)
TOPerGame.rename(columns = {'Rank':'TOPerGame_Rank'}, inplace = True)
WLPct.rename(columns = {'Rank':'WLPct_Rank'}, inplace = True)

# %%
# Confirm changes to column name
FTPct.head()
# Out:
#    FTPct_Rank                            Team  GM    W-L   FT  FTA   FT%
# 0           5  A&M-Corpus Christi (Southland)  33  23-10  550  696  79.0
# 1         150         Abilene Christian (WAC)  30  13-17  414  573  72.3
# 2         153       Air Force (Mountain West)  32  14-18  369  511  72.2
# 3          92                     Akron (MAC)  33  22-11  475  643  73.9
# 4         330              Alabama A&M (SWAC)  33  15-18  425  649  65.5

# %%
# Adding Team and AstPerGame Rank columns to a new dataframe for yearly 
df = AstPerGame[['Team', 'AstPerGame_Rank']].copy()
print(df)
# Out:
#                                Team  AstPerGame_Rank
# 0    A&M-Corpus Christi (Southland)               29
# 1           Abilene Christian (WAC)               28
# 2         Air Force (Mountain West)               39
# 3                       Akron (MAC)              153
# 4                Alabama A&M (SWAC)              202
# ..                              ...              ...
# 347            Wright St. (Horizon)               51
# 348         Wyoming (Mountain West)              315
# 349               Xavier (Big East)                1
# 350               Yale (Ivy League)               70
# 351        Youngstown St. (Horizon)               34
#
# [352 rows x 2 columns]

# %%
# Prepare remaining columns to be inserted into new DF

APG = AstPerGame['AstPerGame_Rank']
ATOR = AstTORatio['AstTORatio_Rank']
BPG = BlocksPerGame['BlocksPerGame_Rank']
FGP = FldGlPct['FldGlPct_Rank']
FGPD = FldGlPctDef['FldGlPctDef_Rank']
FPG = FoulsPerGame['FoulsPerGame_Rank']
FTP= FTPct['FTPct_Rank']
RM = ReboundMargin['ReboundMargin_Rank']
SD = ScoringDefense['ScoringDefense_Rank']
SM = ScoringMargin['ScoringMargin_Rank']
SO = ScoringOffense['ScoringOffense_Rank']
SPG = StlsPerGame['StlsPerGame_Rank']
TPFGP = ThreePtFGPct['ThreePtFGPct_Rank']
TPFGD = ThreePtFGDef['ThreePtFGDef_Rank']
TPFGPG = ThreePtFGPerGame['ThreePtFGPerGame_Rank']
TOM = TOMargin['TOMargin_Rank']
TOPG = TOPerGame['TOPerGame_Rank']
WLP = WLPct['WLPct_Rank']

# %%
# Insert New Columns into Dataframe

df['AstTORatio_Rank'] = ATOR
df['BlocksPerGame_Rank'] = BPG
df['FldGlPct_Rank'] = FGP
df['FldGlPctDef_Rank'] = FGPD
df['FoulsPerGame_Rank'] = FPG
df['FTPct_Rank'] = FTP
df['ReboundMargin_Rank'] = RM
df['ScoringDefense_Rank'] = SD
df['ScoringMargin_Rank'] = SM
df['ScoringOffense_Rank'] = SO
df['StlsPerGame_Rank'] = SPG
df['ThreePtFGPct_Rank'] = TPFGP
df['ThreePtFGDef_Rank'] = TPFGD
df['ThreePtFGPerGame_Rank'] = TPFGPG
df['TOMargin_Rank'] = TOM
df['TOPerGame_Rank'] = TOPG
df['WLPct_Rank'] = WLP

# %%
# confirm addition of columns 
df.head()
# Out:
#                              Team  AstPerGame_Rank  AstTORatio_Rank  \
# 0  A&M-Corpus Christi (Southland)               29               75
# 1         Abilene Christian (WAC)               28               66
# 2       Air Force (Mountain West)               39               63
# 3                     Akron (MAC)              153               80
# 4              Alabama A&M (SWAC)              202              315
#
#    BlocksPerGame_Rank  FldGlPct_Rank  FldGlPctDef_Rank  FoulsPerGame_Rank  \
# 0                 341            108               233                318
# 1                 298            152               342                346
# 2                  73             77               221                193
# 3                 249            181               123                101
# 4                  65            209                96                309
#
#    FTPct_Rank  ReboundMargin_Rank  ScoringDefense_Rank  ScoringMargin_Rank  \
# ...

# %%
# Remove index while exporting
df.to_csv('/Users/bryanwenger/Desktop/Desktop_Master/Coding/github_projects/marchmadness_2023/MarchMadness_2023/data_sets/Yearly_Data_2023.csv',index=False)
